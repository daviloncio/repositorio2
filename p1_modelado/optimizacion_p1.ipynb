# %%
import numpy as np

def funcion(x):
    return x**2-3*x-1
def funcion2(x):
    return x**2+4*x-6
    
    

def root_bracket(f: callable, a: float, b: float, delta=1.)-> tuple:
    '''
    Summary: 
    Se devuelve el intervalo '''
    if a > b:
        raise Exception('a debe de ser menor que b')
    if delta<=0:
        raise Exception('delta debe ser un numero positivo')
    x = a + delta
    f_a = f(a)

    while f_a*f(x)>0:
        
        if x > b:
            return (-np.inf,np.inf)
        x += delta
    return (a,x)

print(root_bracket(funcion,2,4,0.1))

def bisection(f: callable, a: float, b: float, tol=0.001, maxiter=100)-> tuple[float, int]:
    nit = 0
    f_a=f(a)

    while nit<= maxiter :
        mediatriz=(a+b)/2
        f_m=f(mediatriz)
        if abs(f_m )<=tol:
            return (mediatriz,nit)
        
        nit += 1
        if f_a*f_m<0:
            b=mediatriz

        else:
            a=mediatriz
            f_a=f_m

print(bisection(funcion,2,3.4))
def regula_falsi(f: callable, a: float, b: float, tol=0.001, maxiter=100)-> tuple[float, int]:
    nit = 0
    f_a=f(a); f_b=f(b)

    while nit<= maxiter:
        nit +=1
        pendiente=(f_b-f_a)/(b-a)
        x_new=a-f_a/pendiente
        f_x_new=f(x_new)
        if abs(f_x_new)<=tol:
            return (x_new,nit)
        if f_a*f_x_new>0:
            a,f_a=x_new,f_x_new
        else:
            b,f_b=x_new,f_x_new
print(regula_falsi(funcion,2,3.4))

def secant(f: callable, a: float, b: float, tol=0.001, maxiter=100)-> tuple[float, int]:
    nit = 0
    f_a=f(a); f_b=f(b)
    pendiente=(f_b-f_a)/(b-a)
    x_new=a-f_a/pendiente
    while abs(f(x_new)) > tol and nit<= maxiter:
        nit +=1
        if a == b:
            print(nit)
            raise Exception('a y b tiene el mismo valor')
        pendiente=(f_b-f_a)/(b-a)
        x_new=a-f_a/pendiente
        f_x_new=f(x_new)
        if abs(f_x_new)<=tol:
            return (x_new,nit)
        a=b
        b=x_new
       
print(secant(funcion2,-5,6))
# Out:
# (2, 3.4000000000000012)
# (3.3029296875000003, 9)
# (3.302738712065137, 3)
# None
