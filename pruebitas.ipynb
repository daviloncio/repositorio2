# %%
import pandas as pd ; contador=0
ratings=pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/ratings.csv')
ratings['rating_id']=ratings.index
ratings
# Out:
#           userId  movieId  rating   timestamp  rating_id
# 0              1      110     1.0  1425941529          0
# 1              1      147     4.5  1425942435          1
# 2              1      858     5.0  1425941523          2
# 3              1     1221     5.0  1425941546          3
# 4              1     1246     5.0  1425941556          4
# ...          ...      ...     ...         ...        ...
# 26024284  270896    58559     5.0  1257031564   26024284
# 26024285  270896    60069     5.0  1257032032   26024285
# 26024286  270896    63082     4.5  1257031764   26024286
# 26024287  270896    64957     4.5  1257033990   26024287
# 26024288  270896    71878     2.0  1257031858   26024288
#
# [26024289 rows x 5 columns]

# %%
creditos=pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/credits.csv')
creditos
#cast atrbutos: cast_id,character,credit_id,gender,id,name,order,profile_path lista dics
#crew atributos credit_id,department,gender,id,job,name,profile_path lista dics
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
movies_metadata=pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/movies_metadata.csv')

#belongs to colection atrbutos: id, name,poster_path y backdrop path
#genres: id name 
movies_metadata
# Out:
# C:\Users\juanj\AppData\Local\Temp\ipykernel_14392\2437311421.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_metadata=pd.read_csv('C:/Users/juanj/Documents/3ercuatri/modelado/modelado_p1/movies_metadata.csv')
# (0, "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]")
# (1, "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]")
# (2, "[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]")
# (3, "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]")
# (4, "[{'id': 35, 'name': 'Comedy'}]")
# (5, "[{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]")
# (6, "[{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]")
# ...

# %%
pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/keywords.csv')
# Out:
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
# [46419 rows x 2 columns]

# %%
links=pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/links.csv')
links['link_id']=links.index
links
# Out:
#        movieId   imdbId    tmdbId  link_id
# 0            1   114709     862.0        0
# 1            2   113497    8844.0        1
# 2            3   113228   15602.0        2
# 3            4   114885   31357.0        3
# 4            5   113041   11862.0        4
# ...        ...      ...       ...      ...
# 45838   176269  6209470  439050.0    45838
# 45839   176271  2028550  111109.0    45839
# 45840   176273   303758   67758.0    45840
# 45841   176275     8536  227506.0    45841
# 45842   176279  6980792  461257.0    45842
#
# [45843 rows x 4 columns]

# %%
pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/links_small.csv')
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9120   162672  3859980  402672.0
# 9121   163056  4262980  315011.0
# 9122   163949  2531318  391698.0
# 9123   164977    27660  137608.0
# 9124   164979  3447228  410803.0
#
# [9125 rows x 3 columns]

# %%
pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/ratings.csv')
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
pd.read_csv('C:/Users/juanj/OneDrive/Documentos/3er cuatri/modelado/modelado_p1/ratings_small.csv')
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]
